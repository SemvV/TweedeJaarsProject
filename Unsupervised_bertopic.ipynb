# %%
from bertopic import BERTopic
import pandas as pd


df = pd.read_csv('../data/filtered_events_country_code.csv', delimiter=',')
notes = df["clean_notes"].tolist()


topic_model = BERTopic()
topics, _ = topic_model.fit_transform(notes)

topic_model.get_topic_info()
# Out:
#       Topic  Count                                       Name  \
# 0        -1  67429              -1_afd_resident_school_center
# 1         0    890            0_chisinau_sor_buiucani_moldova
# 2         1    675        1_walk_evening_related_unregistered
# 3         2    671            2_animal_circus_animalisti_bear
# 4         3    600  3_gender_equality_predominantly_feminista
# ...     ...    ...                                        ...
# 2650   2649     10           2649_port_viareggio_canal_pissed
# 2651   2650     10      2650_college_picketed_lecturer_andrew
# 2652   2651     10     2651_udu_offset_motorcade_ratification
# 2653   2652     10                2652_rgz_sad_100th_pravacka
# 2654   2653     10              2653_ja21_fortuyn_fvd_racisme
#
#                                          Representation  \
# 0     [afd, resident, school, center, local, cgil, a...
# 1     [chisinau, sor, buiucani, moldova, pa, psrm, m...
# 2     [walk, evening, related, unregistered, street,...
# 3     [animal, circus, animalisti, bear, peta, meat,...
# 4     [gender, equality, predominantly, feminista, e...
# ...                                                 ...
# 2650  [port, viareggio, canal, pissed, kalport, devo...
# 2651  [college, picketed, lecturer, andrew, keele, a...
# 2652  [udu, offset, motorcade, ratification, figueru...
# 2653  [rgz, sad, 100th, pravacka, novi, honor, kneza...
# 2654  [ja21, fortuyn, fvd, racisme, pvv, normalizati...
#
#                                     Representative_Docs
# 0     [morning student teacher parent staged flash m...
# 1     [several sor supporter member protested outsid...
# 2     [evening around 2 400 people took street walk ...
# 3     [call peta around 50 people gathered circus te...
# 4     [people predominantly woman protested ponteved...
# ...                                                 ...
# 2650  [former worker kalport gathered front custom p...
# 2651  [student lecturer member university college un...
# 2652  [farmer around 2 000 tractor participated moto...
# 2653  [farmer student teacher citizen gathered subot...
# 2654  [around 80 activist platform stop racisme stag...
#
# [2655 rows x 5 columns]
