# %%
import pandas as pd

file_name = '../data/2015-06-01-2025-06-01-Europe.csv'

df = pd.read_csv(file_name, delimiter=',')
print(df)
# Out:
#        event_id_cnty       event_date  year  time_precision  \
# 0          UKR228116      23 May 2025  2025               1
# 1          UKR228146      23 May 2025  2025               1
# 2          UKR228615      23 May 2025  2025               1
# 3          UKR228722      23 May 2025  2025               1
# 4          UKR228830      23 May 2025  2025               1
# ...              ...              ...   ...             ...
# 621873          UKR3  01 January 2018  2018               1
# 621874      UKR39146  01 January 2018  2018               1
# 621875      UKR39147  01 January 2018  2018               1
# 621876         UKR31  01 January 2018  2018               1
# 621877         UKR31  01 January 2018  2018               1
#
#              disorder_type                  event_type  \
# 0       Political violence  Explosions/Remote violence
# 1       Political violence  Explosions/Remote violence
# 2       Political violence  Explosions/Remote violence
# 3       Political violence  Explosions/Remote violence
# 4       Political violence  Explosions/Remote violence
# ...                    ...                         ...
# 621873      Demonstrations                    Protests
# 621874      Demonstrations                    Protests
# 621875      Demonstrations                    Protests
# 621876  Political violence                     Battles
# 621877  Political violence                     Battles
#
#                            sub_event_type  \
# 0                        Air/drone strike
# 1                        Air/drone strike
# 2                        Air/drone strike
# 3                        Air/drone strike
# 4       Shelling/artillery/missile attack
# ...                                   ...
# 621873                   Peaceful protest
# 621874                   Peaceful protest
# 621875                   Peaceful protest
# 621876                        Armed clash
# 621877                        Armed clash
#
#                                              actor1  \
# 0       Military Forces of Russia (2000-) Air Force
# 1       Military Forces of Russia (2000-) Air Force
# 2       Military Forces of Russia (2000-) Air Force
# 3       Military Forces of Russia (2000-) Air Force
# 4                 Military Forces of Russia (2000-)
# ...                                             ...
# 621873                         Protesters (Ukraine)
# 621874                         Protesters (Ukraine)
# 621875                         Protesters (Ukraine)
# 621876      NAF: United Armed Forces of Novorossiya
# 621877       Military Forces of Ukraine (2014-2019)
#
#                                             assoc_actor_1  inter1  ...  \
# 0                       Military Forces of Russia (2000-)       8  ...
# 1                       Military Forces of Russia (2000-)       8  ...
# 2                                                     NaN       8  ...
# 3                                                     NaN       8  ...
# 4                                                     NaN       8  ...
# ...                                                   ...     ...  ...
# 621873  National Corps Party; OUN: Organization of Ukr...       6  ...
# 621874  Svoboda; National Corps Party; Sokil; Right Se...       6  ...
# 621875                                     Svoboda; Sokil       6  ...
# 621876                                                NaN       2  ...
# 621877                                                NaN       1  ...
#
#         latitude longitude  geo_precision  \
# 0        51.7339   34.3415              1
# 1        50.9208   35.3411              1
# 2        51.5363   34.1744              1
# 3        52.2216   32.8783              1
# 4        50.8508   35.3941              1
# ...          ...       ...            ...
# 621873   46.6558   32.6178              1
# 621874   49.4285   32.0621              1
# 621875   48.5153   32.2545              1
# 621876   47.1478   37.7881              2
# 621877   47.1478   37.7881              2
#
#                                                   source       source_scale  \
# 0                         Ministry of Defence of Ukraine              Other
# 1                         Ministry of Defence of Ukraine              Other
# 2                         Ministry of Defence of Ukraine              Other
# 3                         Ministry of Defence of Ukraine              Other
# 4                         Ministry of Defence of Ukraine              Other
# ...                                                  ...                ...
# 621873                EuroNews; Ukraine General Newswire  National-Regional
# 621874                                           Svoboda           National
# 621875                                           Svoboda           National
# 621876  Ministry of Defence of Ukraine; OSCE SMM-Ukraine              Other
# 621877  Ministry of Defence of Ukraine; OSCE SMM-Ukraine              Other
#
#                                                     notes fatalities  \
# 0       On 23 May 2025, Russian forces attacked Bila B...          0
# 1       On 23 May 2025, Russian forces attacked Prokho...          0
# 2       On 23 May 2025, Russian forces attacked Hudove...          0
# 3       On 23 May 2025, Russian forces attacked Serhii...          0
# 4       On 23 May 2025, Russian forces attacked Stepok...          0
# ...                                                   ...        ...
# 621873  On 1 January 2018, people, including members o...          0
# 621874  On 1 January 2018, people, including members o...          0
# 621875  On 1 January 2018, about 200 people, including...          0
# 621876  On 1 January 2018, NAF rebel forces fired with...          0
# 621877  On 1 January 2018, NAF rebel forces fired with...          0
#
#                         tags   timestamp  population_best
# 0                        NaN  1748359402              NaN
# 1                        NaN  1748359402              NaN
# 2                        NaN  1748359403              NaN
# 3                        NaN  1748359404              NaN
# 4                        NaN  1748359404              NaN
# ...                      ...         ...              ...
# 621873  crowd size=no report  1732648589              NaN
# 621874  crowd size=no report  1732648590              NaN
# 621875  crowd size=about 200  1732648590              NaN
# 621876                   NaN  1738712947              NaN
# 621877                   NaN  1738712947              NaN
#
# [621878 rows x 29 columns]

# %%
import pandas as pd

file_name = '../data/filtered_events.csv'

df = pd.read_csv(file_name, delimiter=',')
